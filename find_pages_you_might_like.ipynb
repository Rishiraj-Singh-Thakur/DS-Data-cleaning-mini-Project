# %%
def load_data(filename):
    with open(filename,"r")as f:
        return json.load(f)


def find_pages_you_might_like(user_id ,data):
    user_pages = {}
    for user in data["users"]:
        user_pages[user["id"]] = set(user["liked_pages"])

    if user_id not in user_pages:
        return []

    user_liked_pages = user_pages[user_id]
    sujj = {}

    for other_user ,pages in user_pages.items():
        if other_user != user_id:
            shared_pages = user_liked_pages.intersection(pages)

        for page in pages:
            if page not in user_liked_pages:
                sujj[page] = sujj.get(page,0)+len(shared_pages)

    sorted_pages = sorted(sujj.items() ,key=lambda x:x[1],reverse=True)

    return [page_id for page_id ,_ in sorted_pages]

# %%
data = load_data("clear_data.json")
user_id = 1
page_rec = find_pages_you_might_like(user_id, data)
print(f"Pages You Might Like for User {user_id}: {page_rec}")
# Out:
# Pages You Might Like for User 1: [102, 104]
